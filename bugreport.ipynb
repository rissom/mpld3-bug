# %%
AM15spektrum=loadtxt('am15global-ph.txt',skiprows=1)

# %%
import mpld3
mpld3.enable_notebook()
import matplotlib.pylab as plt

# %%
plt.ticklabel_format(style='sci', axis='y',scilimits=(0,0),useLocale=False)
plt.ylabel('Photonen')
plt.grid(True)

# This works:
plt.axis([0, 2000, 0, 1e19])

# This crashes:
# plt.axis([0, 2000, 0, 1e9])

plt.plot(AM15spektrum[:,0],AM15spektrum[:,1])
